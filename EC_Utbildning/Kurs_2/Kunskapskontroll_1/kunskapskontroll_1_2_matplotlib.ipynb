# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
#Object-oriented approach is recommended for complicated plots,
#and when it´s part of a bigger projekt.
#fig, ax = plt.subplots()

#pyplot / Matlab style is easy to use for quick interactive work.
#plt.plot()

#pyplot submodule is used for both.
#plt

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
"""
Figure: The whole figure can be seen as a canvas.

Axes: The plot is attached to the axes. Methods do plotting directly
from the axes. An Axes is an Artist attached to a Figure that contains 
a region for plotting data, and usually includes two (or three in the case 
of 3D) Axis objects (be aware of the difference between Axes and Axis) 
that provide ticks and tick labels to provide scales for the data in the 
Axes. Each Axes also has a title (set via set_title()), an x-label (set 
via set_xlabel()), and a y-label set via set_ylabel()).

Axis: Sets scale and limits, tick and tick-lables.
These objects set the scale and limits and generate ticks (the marks on the 
Axis) and ticklabels (strings labeling the ticks). The location of the 
ticks is determined by a Locator object and the ticklabel strings are 
formatted by a Formatter

Artist: Everything visible is an artist.
Basically, everything visible on the Figure is an Artist 
(even Figure, Axes, and Axis objects). This includes Text objects, 
Line2D objects, collections objects, Patch objects, etc. When the Figure 
is rendered, all of the Artists are drawn to the canvas. 
"""
# Out:
# '\nFigure: The whole figure can be seen as a canvas.\n\nAxes: The plot is attached to the axes. Methods do plotting directly\nfrom the axes. An Axes is an Artist attached to a Figure that contains \na region for plotting data, and usually includes two (or three in the case \nof 3D) Axis objects (be aware of the difference between Axes and Axis) \nthat provide ticks and tick labels to provide scales for the data in the \nAxes. Each Axes also has a title (set via set_title()), an x-label (set \nvia set_xlabel()), and a y-label set via set_ylabel()).\n\nAxis: Sets scale and limits, tick and tick-lables.\nThese objects set the scale and limits and generate ticks (the marks on the \nAxis) and ticklabels (strings labeling the ticks). The location of the \nticks is determined by a Locator object and the ticklabel strings are \nformatted by a Formatter\n\nArtist: Everything visible is an artist.\nBasically, everything visible on the Figure is an Artist \n(even Figure, Axes, and Axis objects). This includes Text objects, \nLine2D objects, collections objects, Patch objects, etc. When the Figure \nis rendered, all of the Artists are drawn to the canvas. \n'

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
#numpy array

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace(-4, 4, 20)
y = x**2
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("y=x^2")
ax.set_xlabel("x-label")
ax.set_ylabel("y-label")
# Out:
# Text(0, 0.5, 'y-label')

# %%
plt.plot(x, y)
plt.title("y = x^2")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
fig, ax = plt.subplots(2, figsize = (10, 10), layout="constrained")
fig.suptitle("Scatter and bar plot", size = 30)

ax[0].scatter(random_data_x, random_data_y)
ax[0].set_title("Scatter plot")

ax[1].bar(names, values)
ax[1].set_title("Bar plot")
# Out:
# Text(0.5, 1.0, 'Bar plot')
